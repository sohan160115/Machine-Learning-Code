# %%
pip install pandas

# %%
import pandas as pd
from keras.models import Sequential
from keras.layers import Dense
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score
import numpy as np

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
df=pd.read_csv("/content/drive/MyDrive/Colab Notebooks/Crop.csv")
input=df.iloc[:,0:3]
output=df.iloc[:,3:]
x_train,x_test,y_train,y_test=train_test_split(input,output,test_size=0.2)

# %%
#defining layers
model=Sequential()
model.add(Dense(100,input_dim=3,activation='relu'))
model.add(Dense(100,input_dim=100,activation='relu'))
model.add(Dense(100,input_dim=100,activation='relu'))
model.add(Dense(1,activation='linear'))

# Compiling the model
model.compile(loss="mean_squared_error",optimizer="adam",metrics=["mse"])
# print(model.summary())
history=model.fit(x_train,y_train,epochs=2700,batch_size=10,validation_split=0.15,validation_data=None)

#prediction
y_true = np.array(y_test)
y_pred = np.array(model.predict(x_test))
r2_score(y_true,y_pred)
# Out:
# Streaming output truncated to the last 5000 lines.
# Epoch 201/2700
# 150/150 [==============================] - 1s 3ms/step - loss: 12.7634 - mse: 12.7634 - val_loss: 14.3174 - val_mse: 14.3174
# Epoch 202/2700
# 150/150 [==============================] - 0s 3ms/step - loss: 12.8901 - mse: 12.8901 - val_loss: 11.8302 - val_mse: 11.8302
# Epoch 203/2700
# 150/150 [==============================] - 0s 3ms/step - loss: 13.1955 - mse: 13.1955 - val_loss: 11.6770 - val_mse: 11.6770
# Epoch 204/2700
# 150/150 [==============================] - 0s 3ms/step - loss: 13.0486 - mse: 13.0486 - val_loss: 11.6130 - val_mse: 11.6130
# Epoch 205/2700
# 150/150 [==============================] - 1s 3ms/step - loss: 12.3131 - mse: 12.3131 - val_loss: 11.5873 - val_mse: 11.5873
# Epoch 206/2700
# 150/150 [==============================] - 0s 3ms/step - loss: 12.5728 - mse: 12.5728 - val_loss: 13.3099 - val_mse: 13.3099
# Epoch 207/2700
# ...

# %%
y_pred = np.array(model.predict([[20,82,203]]))
print(y_pred)
# Out:
# [[0.3253684]]

# %%
model.save_weights('mymodel_weights')
model.save('mymodel.h5')

# %%
# !pip install tensorflowjs
# Out:
# ...
#      |████████████████████████████████| 77 kB 3.5 MB/s
# ...

# %%
import tensorflowjs as tfjs
tfjs.converters.save_keras_model(model,"model_for_javascript")
